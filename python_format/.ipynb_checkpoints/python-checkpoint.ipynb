# %%
# Out:
# 1 2

# %%
# Out:
# Package                Version       Location
# ---------------------- ------------- -----------------------------
# absl-py                0.9.0
# addict                 2.2.1
# albumentations         0.4.3
# appdirs                1.4.4
# astroid                2.3.3
# astunparse             1.6.3
# asynctest              0.13.0
# atomicwrites           1.3.0
# attrs                  19.3.0
# backcall               0.2.0
# cachetools             4.1.0
# certifi                2020.4.5.1
# cffi                   1.14.0
# chardet                3.0.4
# click                  6.7
# codecov                2.0.16
# colorama               0.4.3
# coverage               5.0.3
# cycler                 0.10.0
# Cython                 0.29.15
# dataclasses            0.8
# decorator              4.4.1
# entrypoints            0.3
# flake8                 3.7.9
# Flask                  0.12.2
# gast                   0.3.3
# google-auth            1.14.2
# google-auth-oauthlib   0.4.1
# ...
